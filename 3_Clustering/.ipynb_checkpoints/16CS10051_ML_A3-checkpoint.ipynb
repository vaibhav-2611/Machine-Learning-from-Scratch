# %%
import pandas as pd
import numpy as np
import sys
import numpy
import math
import networkx as nx
import matplotlib.pyplot as plt
numpy.set_printoptions(threshold=sys.maxsize)

# %% [markdown]
# ### DataSet

# %%
data = pd.read_csv('AAAI.csv')
data
# Out:
#                                                  Title  \
# 0    The cascade auction – a mechanism for deterrin...
# 1    Basis Adaptation for Sparse Nonlinear Reinforc...
# 2    Optimal Coalition Structures in Cooperative Gr...
# 3    External Memory Best-First Search for Multiple...
# 4    Posted Prices Exchange for Display Advertising...
# 5    Gradient Networks for Shape-Based Object Insta...
# 6    Unified Constraint Propagation on Multi-View Data
# 7    Progression of Decomposed Situation Calculus T...
# 8              How to Cut a Cake Before the Party Ends
# 9    Reciprocal Hash Tables for Nearest Neighbor Se...
# 10                        Automated Workflow Synthesis
# 11   Video Saliency Detection via Dynamic Consisten...
# 12          Symmetry-Aware Marginal Density Estimation
# 13   Improving WalkSAT for Random $k$-Satisfiabilit...
# 14   A Generalized Student-t Based Approach to Mixe...
# 15    Causal Transportability with Limited Experiments
# 16   Rank Aggregation via Low-rank and Structured-s...
# 17   Computational Aspects of Nearly Single-Peaked ...
# 18   On the Value of using Group Discounts under Pr...
# 19            Bundling Attacks in Judgment Aggregation
# 20   Bounding the Cost of Stability in Games over I...
# 21   Formalizing Hierarchical Clustering as Integer...
# 22   Clustering with Complex Constraints - Algorith...
# 23   GiSS: Combining Gibbs Sampling and SampleSearc...
# 24   An Agent Design for Repeated Negotiation and I...
# 25         A Maximum K-Min Approach for Classification
# 26   RockIt: Exploiting Parallelism and Symmetry fo...
# 27   Multi-Armed Bandit with Budget Constraint and ...
# 28   Abstract Preference Frameworks — a Unifying Pe...
# 29          Equilibria of Online Scheduling Algorithms
# ..                                                 ...
# 120  Assumption-Based Planning: Generating plans an...
# 121  Analyzing the effectiveness of adversary model...
# 122  Hypothesis Exploration for Malware Detection u...
# 123  Algorithms for strong Nash equilibrium with mo...
# 124  Decoupling the Multiagent Disjunctive Temporal...
# 125  Online Lazy Updates for Portfolio Selection wi...
# 126       Teamwork with Limited Knowledge of Teammates
# 127  Greedy or Not?   Local search move selection f...
# 128  Learning Integrated Symbolic and Continuous Ac...
# 129  Truncated LPA* : Faster Replanning by Exploiti...
# 130  Effective Bilingual Constraints for Semi-super...
# 131  A General Formal Framework for Pathfinding Pro...
# 132  Multiagent Learning with a Noisy Global Reward...
# 133  Modelling and Control of Mixed Observability M...
# 134  Resolution and Parallelizability: Barriers to ...
# 135  Ties Matter: Complexity of Manipulation when T...
# 136  Solving security games on graphs via marginal ...
# 137  Sample Complexity and Performance Bounds for N...
# 138  PAC Optimal Exploration in Continuous Space Ma...
# 139  A Fast Pairwise Heuristic for Planning under U...
# 140  Sensitivity of diffusion dynamics to network u...
# 141  Automatic Identification of Conceptual Metapho...
# 142                     Model-Lite Case-Based Planning
# 143  Scalable Lifelong Learning with Active Task Se...
# 144  Continuous Conditional Random Fields for Effic...
# 145  Probabilistic Sense Sentiment Similarity throu...
# 146  Strategic Behavior when Allocating Indivisible...
# 147  A Pattern Matching Based Graphical Model for Q...
# 148  Grounding Natural Language References to Unvis...
# 149     Story Generation with Crowdsourced Plot Graphs
#
#                                               Keywords  \
# 0         Mediators\nAuctions\nCollusion\nAd Exchanges
# 1    Reinforcement learning\nSparsity\nMirror desce...
# 2    Cooperative Game Theory\nCoalition Structure G...
# 3    External-Memory Search\nParallel Search\nMulti...
# 4    Display Advertising\nDynamic Pricing\nMarket E...
# 5    object detection\ninstance detection\nshape\ng...
# 6    pairwise constraint propagation\nsemi-supervis...
# 7    reasoning about actions\ndecomposition of logi...
# 8    Cake cutting\nFair division\nComputational soc...
# 9    locality sensitive hashing\nnearest neighbor s...
# 10   human computation\ncrowd computing\nprogram sy...
# 11   Video Saliency Map\nSpatio-Temporal Attention ...
# 12   statistical relational learning\nMarkov logic ...
# 13   WalkSAT\nRandom $k$-Satisfiability Problem\nMu...
# 14   Outlier Detection\nAnomaly Detection\nMixed Ty...
# 15   Causality\nTransportability\nMeta-analysis\nTr...
# 16   Rank aggregation\nLow-rank matrices\nStructure...
# 17   Computational social choice\n(Nearly) Single-p...
# 18   Group discounts\nPrice competition\nStable mat...
# 19   Bundling\nJudgment Aggregation\nAverage case c...
# 20   Cooperative games\nSocial networks\nCost of st...
# 21   Hierarchical Clustering\nInteger Programming\n...
# 22   Constrained clustering\nQuadratic programming\...
# 23   Probabilistic Graphical Models\nApproximate In...
# 24   Human-Computer Decision-Making\nHuman-Computer...
# 25              Classification\nMaximin\nMaximum K Min
# 26   Statistical Relational Models\nMAP Inference\n...
# 27    multi-armed bandit\nonline learning\nad exchange
# 28   Reasoning with Preferences\nStrong Equivalence...
# 29   Online Games\nEquilibrium Analysis\nScheduling...
# ..                                                 ...
# 120  Planning under incomplete knowledge\nExplanati...
# 121  Game Theory\nHuman Behavior\nQuantal Response\...
# 122     Planning\nApplication\nReasoning about actions
# 123  non-cooperative game theory\nStrong Nash equil...
# 124  Temporal Decoupling\nMultiagent Scheduling\nDi...
# 125  Online learning\nPortfolio selection\nTransact...
# 126  Multiagent Teamwork\nLimited Knowledge\nAd Hoc...
# 127   stochastic local search\nSAT\nempirical analysis
# 128  Action Modeling\nCombined Symbolic/Continuous ...
# 129  Heuristic Search\nPath Planning\nIncremental S...
# 130  Gibbs sampling for factored models\nbilingual ...
# 131  knowledge representation\nanswer set programmi...
# 132  Multiagent Coordination\nReinforcement Learnin...
# 133  predictive states\nmixed observability\nmodel ...
# 134  Resolution\nSatisfiability\nParallel\nSAT\nCla...
# 135  Social choice\nVoting\nManipulation\nComputati...
# 136  computational game theory\nstackelberg games\n...
# 137                   MDP\nALP\nReinforcement Learning
# 138  MDPs\nPAC-optimal\nExploration\nReinforcement ...
# 139  Planning under uncertainty\nDecision Making\nM...
# 140  diffusion on graphs\nindependent cascades mode...
# 141  conceptual metaphor\ncognitive linguistics\nna...
# 142  Model-lite planning\ncase-based planning\nplan...
# 143  lifelong learning\nmulti-task learning\nactive...
# 144  structured regression\nconditional random fiel...
# 145  Sentiment Similarity\nIndirect yse/no Question...
# 146  Fair division\nElicition free protocol\nBackwa...
# 147  Opinion Question\nSubjectivity Detection\nOpin...
# 148  Human-robot interaction\nIntegrated perception...
# 149  Story generation\nNarrative intelligence\nKnow...
#
#                                                 Topics  \
# 0    Auctions and Market-Based Systems\nE-Commerce\...
# 1    Dimension Reduction/Feature Selection\nOnline ...
# 2          Coordination and Collaboration\nGame Theory
# 3    Heuristic Search\nEvaluation and Analysis (Sea...
# 4    Auctions and Market-Based Systems\nE-Commerce\...
# 5           Vision, Object Recognition, and Perception
# 6    Relational/Graph-Based Learning\nSemisupervise...
# 7                        Action, Change, and Causality
# 8             Mechanism Design\nSocial Choice / Voting
# 9    Search (General/Other)\nInformation Retrieval\...
# 10   Distributed Problem Solving\nComputational Soc...
# 11                                  Cognitive Modeling
# 12   Big Data / Scalability\nMachine Learning (Gene...
# 13   SAT and CSP: Solvers and Tools\nHeuristic Sear...
# 14   Bayesian Learning\nData Mining and Knowledge D...
# 15    Action, Change, and Causality\nBayesian Networks
# 16                        Preferences/Ranking Learning
# 17                              Social Choice / Voting
# 18   E-Commerce\nGame Theory\nMechanism Design\nUnc...
# 19   Game Theory\nMechanism Design\nSocial Choice /...
# 20   Coordination and Collaboration\nGame Theory\nM...
# 21   Constraint Optimization\nOptimization\nOntolog...
# 22     Clustering\nData Mining and Knowledge Discovery
# 23   Bayesian Networks\nGraphical Models (Other)\nP...
# 24   Negotiation and Contract-Based Systems\nHuman-...
# 25                                      Classification
# 26   Constraint Optimization\nSAT and CSP: Evaluati...
# 27                         Online Learning\nE-Commerce
# 28   Nonmonotonic Reasoning\nPreferences\nQualitati...
# 29                                         Game Theory
# ..                                                 ...
# 120  Common-Sense Reasoning\nDiagnosis and Abductiv...
# 121  Evaluation and Analysis (Multiagent Systems)\n...
# 122  Action, Change, and Causality\nDiagnosis and A...
# 123    Game Theory\nMultiagent Systems (General/other)
# 124  Coordination and Collaboration\nDistributed Pr...
# 125  Optimization\nOnline Learning\nTime-Series/Dat...
# 126  Transfer, Adaptation, Multitask Learning\nCoor...
# 127  SAT and CSP: Evaluation and Analysis\nSAT and ...
# 128  Action, Change, and Causality\nGeometric, Spat...
# 129  Heuristic Search\nReplanning and Plan Repair\n...
# 130                             Information Extraction
# 131  Logic Programming\nNonmonotonic Reasoning\nMul...
# 132  Reinforcement Learning\nCoordination and Colla...
# 133        Reinforcement Learning\nMultiagent Learning
# 134  SAT and CSP: Evaluation and Analysis\nSAT and ...
# 135                             Social Choice / Voting
# 136                          Optimization\nGame Theory
# 137                             Reinforcement Learning
# 138                             Reinforcement Learning
# 139  Planning (General/Other)\nUncertainty in AI (G...
# 140  Agent-based Simulation and Emergent Behavior\n...
# 141  Unsupervised Learning (Other)\nNatural Languag...
# 142  Case-Based Reasoning\nDeterministic Planning\n...
# 143  Active Learning\nTransfer, Adaptation, Multita...
# 144  Big Data / Scalability\nGraphical Model Learni...
# 145  Information Extraction\nQuestion Answering\nNa...
# 146                      Game Theory\nMechanism Design
# 147        Natural Language Processing (General/Other)
# 148  Natural Language Processing (General/Other)\nR...
# 149  Knowledge-Based Systems (General/Other)\nMachi...
#
#                              High-Level Keyword(s)  \
# 0                               Multiagent Systems
# 1                                 Machine Learning
# 2                               Multiagent Systems
# 3                Heuristic Search and Optimization
# 4                               Multiagent Systems
# 5                                         Robotics
# 6                                 Machine Learning
# 7           Knowledge Representation and Reasoning
# 8                               Multiagent Systems
# 9                                 Machine Learning
# 10                              Multiagent Systems
# 11                        Multidisciplinary Topics
# 12                                Machine Learning
# 13                  Constraints and Satisfiability
# 14                                Machine Learning
# 15          Knowledge Representation and Reasoning
# 16                                Machine Learning
# 17                              Multiagent Systems
# 18                              Multiagent Systems
# 19                              Multiagent Systems
# 20                              Multiagent Systems
# 21                                Machine Learning
# 22                                Machine Learning
# 23          Knowledge Representation and Reasoning
# 24                        Multidisciplinary Topics
# 25                                Machine Learning
# 26                  Constraints and Satisfiability
# 27                                Machine Learning
# 28          Knowledge Representation and Reasoning
# 29                              Multiagent Systems
# ..                                             ...
# 120  Reasoning about Plans, Processes, and Actions
# 121                       Multidisciplinary Topics
# 122  Reasoning about Plans, Processes, and Actions
# 123                             Multiagent Systems
# 124  Reasoning about Plans, Processes, and Actions
# 125              Heuristic Search and Optimization
# 126                               Machine Learning
# 127                 Constraints and Satisfiability
# 128  Reasoning about Plans, Processes, and Actions
# 129  Reasoning about Plans, Processes, and Actions
# 130                    Natural Language Processing
# 131                                       Robotics
# 132                               Machine Learning
# 133                               Machine Learning
# 134                 Constraints and Satisfiability
# 135                             Multiagent Systems
# 136                             Multiagent Systems
# 137                               Machine Learning
# 138                               Machine Learning
# 139  Reasoning about Plans, Processes, and Actions
# 140                             Multiagent Systems
# 141                    Natural Language Processing
# 142  Reasoning about Plans, Processes, and Actions
# 143                               Machine Learning
# 144                               Machine Learning
# 145                    Natural Language Processing
# 146                             Multiagent Systems
# 147                    Natural Language Processing
# 148                    Natural Language Processing
# 149                       Multidisciplinary Topics
#
#                                               Abstract
# 0    We introduce a sealed bid auction of a single ...
# 1    This paper presents a new approach to basis ad...
# 2    Representation  languages for coalitional game...
# 3    Multiple sequence alignment (MSA) is a central...
# 4    We propose a new market design for display adv...
# 5    We present a novel framework for shape-based t...
# 6    This paper presents a unified framework for in...
# 7    In many tasks related to reasoning about conse...
# 8    For decades researchers have struggled with th...
# 9    Recent years have witnessed the success of has...
# 10   By coordinating efforts from humans and machin...
# 11   Human vision system actively seeks salient reg...
# 12   Concepts from the field of statistics are leve...
# 13   Stochastic local search (SLS) algorithms are w...
# 14   Anomaly detection for mixed-type data is an im...
# 15   We address the problem of transferring causal ...
# 16   Rank aggregation, which combines multiple indi...
# 17   Manipulation, bribery, and control are well-st...
# 18   The increasing use of group discounts\nhas pro...
# 19   We consider judgment aggregation over multiple...
# 20   We study stability of cooperative games played...
# 21   Hierarchical clustering is typically implement...
# 22   Clustering with constraints is an important an...
# 23   Mixed probabilistic and deterministic graphica...
# 24   Many negotiations in the real world are charac...
# 25   Over the past decades, Maximin/Minimax Classif...
# 26   In this paper we present RockIt a maximum a-po...
# 27   We study the multi-armed bandit problems with ...
# 28   To study mechanisms common across a variety of...
# 29   We describe a model for competitive online sch...
# ..                                                 ...
# 120  Many practical planning problems necessitate t...
# 121  Recent deployments of Stackelberg security gam...
# 122  In this paper we apply AI planning to address ...
# 123  Strong Nash equilibrium (SNE) is an appealing ...
# 124  The Multiagent Disjunctive Temporal Problem (M...
# 125  With the ever increasing amount of data, parti...
# 126  While great strides have been made in multiage...
# 127  Stochastic local search (SLS) is the dominant ...
# 128  Long-living autonomous agents must be able to ...
# 129  Incremental heuristic searches try to reuse th...
# 130  Most semi-supervised methods in Natural Langua...
# 131  Pathfinding for a single agent is the problem ...
# 132  Scaling multiagent reinforcement learning to d...
# 133  Learning accurate models of agent behaviours i...
# 134  Recent attempts to create versions of Satisfia...
# 135  We study the impact on strategic voting of tie...
# 136  Security games involving the allocation of mul...
# 137  One of the most difficult tasks in value funct...
# 138  Current exploration algorithms can be classifi...
# 139  POMDP (Partially Observable Markov Decision Pr...
# 140  Simple diffusion processes on networks have be...
# 141  Complete natural language understanding requir...
# 142  There is increasing awareness in the planning ...
# 143  In a lifelong learning framework, an agent acq...
# 144  When used for structured regression, powerful ...
# 145  Sentiment Similarity of word pairs reflects th...
# 146  We study a simple sequential allocation mechan...
# 147  This paper presents the results of developing ...
# 148  While much research exists on resolving spatia...
# 149  Story generation is the problem of automatical...
#
# [150 rows x 5 columns]

# %%
def Jaccard_Coeff(S1, S2):
    return len(S1.intersection(S2))/len(S1.union(S2))

def Distance_single_linkage(L1, L2):
    temp = math.inf
    for seti in L1:
        for setj in L2:
            distance = 1-Jaccard_Coeff(seti,setj)
            temp = min(temp,distance)
    return temp

def Distance_complete_linkage(L1, L2):
    temp = -math.inf
    for seti in L1:
        for setj in L2:
            distance = 1-Jaccard_Coeff(seti,setj)
            temp = max(temp,distance)
    return temp

# %% [markdown]
# ###  Hierarchical Clustering method with Single Linkage

# %%
def Cluster_Single_Linkage():
    data = pd.read_csv('AAAI.csv')
    Points = dict()
    Docs   = dict()
    for i in range(0,data.shape[0]):
        Points[i]=[]
        Docs[i] = []
        temp = set()
        for item in data.iloc[i,2].split('\n'):
            temp.add(item)
        Points[i].append(temp)
        Docs[i].append(i)

    Number_of_clusters = 9
    Current_number_of_clusters = len(Points)
    while(Current_number_of_clusters>Number_of_clusters):
        temp = math.inf
        for i in Points:
            for j in Points:
                if i==j:
                    continue
                x = Distance_single_linkage(Points[i],Points[j])
                if(temp>x):
                    cluster1 = i
                    cluster2 = j
                    temp = x
        L1 = Points[cluster1]
        L2 = Points[cluster2]
        L = L1 + L2
        Points.pop(cluster1)
        Points.pop(cluster2)
        Points[cluster1] = L
        Current_number_of_clusters -= 1
        L1 = Docs[cluster1]
        L2 = Docs[cluster2]
        L = L1 + L2
        Docs.pop(cluster1)
        Docs.pop(cluster2)
        Docs[cluster1] = L
    for i in Docs:
        Docs[i].sort()
    return Points, Docs

# %%
Clusters1, Ids1 = Cluster_Single_Linkage()
counter = 1
print("\nBy Single Linkage:")
for i in Ids1:
    print("Size:", len(Ids1[i]), "Cluster",counter,": ",Ids1[i])
    counter +=1
# Out:
# By Single Linkage:
# Size: 1 Cluster 1 :  [52]
# Size: 1 Cluster 2 :  [75]
# Size: 1 Cluster 3 :  [77]
# Size: 1 Cluster 4 :  [107]
# Size: 1 Cluster 5 :  [128]
# Size: 45 Cluster 6 :  [0, 1, 2, 4, 8, 10, 17, 18, 19, 20, 24, 28, 29, 31, 37, 39, 49, 50, 55, 67, 68, 70, 74, 76, 79, 81, 86, 87, 95, 96, 106, 112, 116, 117, 121, 123, 126, 131, 132, 133, 135, 136, 137, 138, 146]
# Size: 64 Cluster 7 :  [3, 5, 6, 9, 11, 14, 16, 21, 22, 25, 27, 30, 32, 33, 36, 40, 41, 42, 43, 44, 45, 46, 51, 54, 56, 57, 60, 61, 63, 64, 65, 69, 72, 78, 80, 84, 89, 90, 91, 93, 94, 97, 98, 99, 100, 101, 102, 103, 104, 109, 110, 111, 114, 115, 119, 130, 140, 141, 143, 144, 145, 147, 148, 149]
# Size: 22 Cluster 8 :  [7, 12, 13, 15, 23, 26, 35, 47, 48, 53, 59, 62, 66, 73, 83, 85, 88, 92, 113, 118, 127, 134]
# Size: 14 Cluster 9 :  [34, 38, 58, 71, 82, 105, 108, 120, 122, 124, 125, 129, 139, 142]

# %% [markdown]
# ###  Hierarchical Clustering method with Complete Linkage

# %%
def Cluster_Complete_Linkage():
    data = pd.read_csv('AAAI.csv')
    Points = dict()
    Docs   = dict()
    for i in range(0,data.shape[0]):
        Points[i]=[]
        Docs[i] = []
        temp = set()
        for item in data.iloc[i,2].split('\n'):
            temp.add(item)
        Points[i].append(temp)
        Docs[i].append(i)

    Number_of_clusters = 9
    Current_number_of_clusters = len(Points)
    while(Current_number_of_clusters>Number_of_clusters):
        temp = math.inf
        for i in Points:
            for j in Points:
                if i==j:
                    continue
                x = Distance_complete_linkage(Points[i],Points[j])
                if(temp>x):
                    cluster1 = i
                    cluster2 = j
                    temp = x
        L1 = Points[cluster1]
        L2 = Points[cluster2]
        L = L1 + L2
        Points.pop(cluster1)
        Points.pop(cluster2)
        Points[cluster1] = L
        Current_number_of_clusters -= 1
        L1 = Docs[cluster1]
        L2 = Docs[cluster2]
        L = L1 + L2
        Docs.pop(cluster1)
        Docs.pop(cluster2)
        Docs[cluster1] = L
    for i in Docs:
        Docs[i].sort()
    return Points, Docs

# %%
Clusters2, Ids2 = Cluster_Complete_Linkage()
counter = 1
print("\nBy Complete Linkage:")
for i in Ids2:
    print("Size:", len(Ids2[i]),"Cluster",counter,": ",Ids2[i])
    counter +=1
# Out:
# By Complete Linkage:
# Size: 11 Cluster 1 :  [46, 57, 60, 62, 78, 84, 90, 92, 104, 130, 145]
# Size: 11 Cluster 2 :  [6, 7, 11, 15, 32, 35, 59, 94, 97, 101, 143]
# Size: 14 Cluster 3 :  [24, 25, 37, 39, 41, 50, 70, 89, 91, 100, 111, 116, 121, 144]
# Size: 12 Cluster 4 :  [0, 4, 9, 10, 18, 27, 44, 47, 53, 76, 83, 140]
# Size: 16 Cluster 5 :  [12, 23, 34, 61, 63, 64, 65, 85, 107, 115, 118, 119, 139, 141, 147, 148]
# Size: 18 Cluster 6 :  [1, 8, 19, 22, 36, 45, 52, 69, 72, 79, 106, 109, 110, 117, 128, 133, 137, 138]
# Size: 16 Cluster 7 :  [5, 28, 33, 56, 66, 73, 74, 75, 77, 81, 88, 93, 112, 114, 131, 149]
# Size: 23 Cluster 8 :  [3, 13, 14, 26, 30, 38, 40, 42, 48, 54, 58, 71, 82, 99, 103, 105, 113, 120, 122, 127, 129, 134, 142]
# Size: 29 Cluster 9 :  [2, 16, 17, 20, 21, 29, 31, 43, 49, 51, 55, 67, 68, 80, 86, 87, 95, 96, 98, 102, 108, 123, 124, 125, 126, 132, 135, 136, 146]

# %% [markdown]
# ### Girvan-Newman clustering algorithm

# %%
def create_Graph(file, threshold):
    data = pd.read_csv(file)
    Points = dict()
    for i in range(0,data.shape[0]):
        temp = set()
        for item in data.iloc[i,2].split('\n'):
            temp.add(item)
        Points[i]=temp
        
    # Creating a Graph    
    G = nx.Graph()
    for i in range(0,len(Points)):
        G.add_node(i)
        for j in range(i+1,len(Points)):
            x = Jaccard_Coeff(Points[i],Points[j])
            if(x >= threshold):
                G.add_edge(i, j, weight=1-x)
    # Removing edge one by one based on Betweenness Centrality
    while(nx.number_connected_components(G)<9):
        L=nx.edge_betweenness_centrality(G,normalized=True)
        temp = -math.inf
        for e in L:
            if(temp<L[e]):
                edge=e
        G.remove_edge(*edge)
    return G

def get_9_clusters(G):
    CLUSTERS = dict()
    counter = 0
    res = []
    for i in nx.connected_components(G):
        res.append((i,len(i)))
    res = sorted(res, key=lambda x:(-x[1],x[0]))
    for i in res:
        if(counter==9):
            break
        CLUSTERS[counter] = i[0]
        counter+=1
    return CLUSTERS

# %%
threshold = 0.279
G = create_Graph("AAAI.csv",threshold)
print("Graph when Threshold =",threshold)
nx.draw(G, with_labels=False, node_size=20)
CLUSTERS = get_9_clusters(G)
plt.show()
for i in CLUSTERS:
    print("Size:", len(CLUSTERS[i]),"Cluster",i+1,": ",CLUSTERS[i])
# Out:
# Graph when Threshold = 0.279
# /home/vaibhav/anaconda3/lib/python3.7/site-packages/networkx/drawing/nx_pylab.py:611: MatplotlibDeprecationWarning: isinstance(..., numbers.Number)
#   if cb.is_numlike(alpha):
# Size: 53 Cluster 1 :  {130, 5, 6, 11, 141, 14, 143, 16, 145, 144, 147, 148, 21, 22, 25, 32, 33, 36, 40, 41, 42, 45, 46, 51, 54, 56, 57, 60, 61, 63, 64, 65, 69, 72, 78, 80, 84, 89, 90, 91, 93, 94, 97, 100, 101, 103, 104, 109, 110, 111, 114, 115, 119}
# Size: 37 Cluster 2 :  {0, 1, 2, 4, 133, 132, 135, 8, 136, 137, 138, 17, 18, 19, 20, 146, 24, 29, 31, 37, 39, 49, 50, 55, 67, 68, 70, 76, 79, 86, 95, 96, 106, 116, 117, 123, 126}
# Size: 7 Cluster 3 :  {66, 73, 13, 47, 48, 83, 88}
# Size: 6 Cluster 4 :  {35, 7, 15, 59, 92, 62}
# Size: 6 Cluster 5 :  {38, 105, 142, 120, 122, 125}
# Size: 5 Cluster 6 :  {12, 85, 118, 23, 26}
# Size: 4 Cluster 7 :  {34, 139, 58, 82}
# Size: 4 Cluster 8 :  {112, 81, 74, 131}
# Size: 3 Cluster 9 :  {99, 3, 30}

# %% [markdown]
# ### Normalized Mutual Information (NMI)

# %%
def I(Clusters, Label, N):
    Total = 0.0
    for W in Clusters:
        Wk = Clusters[W]
        for C in Label:
            Cj = Label[C]
            s1 = set(Wk)
            s2 = set(Cj)
            x = len(s1.intersection(s2))
            if(x != 0):
                z = math.log((N*x)/(len(s1)*len(s2)))
                Total += (x/N)*z
    return Total
def H(W,N):
    Total = 0.0
    for w in W:
        Wk = W[w]
        s1 = set(Wk)
        x = len(s1)
        if(x != 0):
            Total += (x/N)*math.log(x/N)
    return -Total

def NMI(Clusters, Label, N):
    x = I(Clusters, Label, N)
    y = H(Clusters,N)
    z = H(Label,N)
    return (2.0*x)/(y+z)

# %%
Label = dict()
for i in range(0,len(data)):
    if(data.iloc[i,3] not in Label):
        Label[data.iloc[i,3]]=[]
    Label[data.iloc[i,3]].append(i)

print("NMI for Hierarchical Clustering method with Single Linkage")
print(NMI(Ids1, Label, len(data)),"\n\n")

print("NMI for Hierarchical Clustering method with Complete Linkage")
print(NMI(Ids2, Label, len(data)),"\n\n")

print("NMI for Girvan-Newman clustering algorithm")
print(NMI(CLUSTERS, Label, len(data)),"\n\n")


print("NMI for Girvan-Newman clustering algorithm")
ans = -math.inf
best_thres = 0.0
for threshold in np.arange(0.999,0.001,-0.03): 
    G=create_Graph("AAAI.csv",threshold)
    CLUSTERS = get_9_clusters(G)
    x = NMI(CLUSTERS, Label, len(data))
    if(x>ans):
        best_thres = threshold
        ans = x
    print("Threshold:",round(threshold,5),"  \tBest_Threshold:", round(best_thres,5),"\tMax_NMI:",ans)
# Out:
# NMI for Hierarchical Clustering method with Single Linkage
# 0.5066227644244067
#
#
# NMI for Hierarchical Clustering method with Complete Linkage
# 0.3872525324557641
#
#
# NMI for Girvan-Newman clustering algorithm
# 0.5453413235246195
#
#
# NMI for Girvan-Newman clustering algorithm
# Threshold: 0.999   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.969   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.939   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.909   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.879   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.849   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.819   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.789   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.759   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.729   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.699   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.669   	Best_Threshold: 0.999 	Max_NMI: 0.17657887391666793
# Threshold: 0.639   	Best_Threshold: 0.639 	Max_NMI: 0.19288852050387326
# Threshold: 0.609   	Best_Threshold: 0.639 	Max_NMI: 0.19288852050387326
# Threshold: 0.579   	Best_Threshold: 0.579 	Max_NMI: 0.20575705950689016
# Threshold: 0.549   	Best_Threshold: 0.579 	Max_NMI: 0.20575705950689016
# Threshold: 0.519   	Best_Threshold: 0.579 	Max_NMI: 0.20575705950689016
# Threshold: 0.489   	Best_Threshold: 0.489 	Max_NMI: 0.43461632368966047
# Threshold: 0.459   	Best_Threshold: 0.489 	Max_NMI: 0.43461632368966047
# Threshold: 0.429   	Best_Threshold: 0.489 	Max_NMI: 0.43461632368966047
# Threshold: 0.399   	Best_Threshold: 0.489 	Max_NMI: 0.43461632368966047
# Threshold: 0.369   	Best_Threshold: 0.489 	Max_NMI: 0.43461632368966047
# Threshold: 0.339   	Best_Threshold: 0.489 	Max_NMI: 0.43461632368966047
# Threshold: 0.309   	Best_Threshold: 0.309 	Max_NMI: 0.5272084210000898
# Threshold: 0.279   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.249   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.219   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.189   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.159   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.129   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.099   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.069   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.039   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
# Threshold: 0.009   	Best_Threshold: 0.279 	Max_NMI: 0.5453413235246195
